# %%
# Imports
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the Breast Cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=87)

# Neural network model with additional dense layers
model = Sequential()
model.add(Dense(20, input_dim=X_train.shape[1], activation='relu'))  # Adjusted input_dim for Breast Cancer dataset
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=10, verbose=1)

# Model summary
print(model.summary())

# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/100
# 43/43 [==============================] - 3s 6ms/step - loss: 0.4219 - accuracy: 0.8826
# Epoch 2/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 0.9624
# Epoch 3/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9812
# Epoch 4/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0569 - accuracy: 0.9859
# Epoch 5/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0445 - accuracy: 0.9906
# Epoch 6/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9930
# Epoch 7/100
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0301 - accuracy: 0.9953
# Epoch 8/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 0.9953
# Epoch 9/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9977
# Epoch 10/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9977
# Epoch 11/100
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 0.9977
# Epoch 12/100
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0131 - accuracy: 0.9977
# Epoch 13/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9977
# Epoch 14/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 0.9977
# Epoch 15/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9977
# Epoch 16/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9953
# Epoch 17/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9977
# Epoch 18/100
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9977
# Epoch 19/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9977
# Epoch 20/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 21/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 22/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 24/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 29/100
# 43/43 [==============================] - 0s 3ms/step - loss: 9.0408e-04 - accuracy: 1.0000
# Epoch 30/100
# 43/43 [==============================] - 0s 7ms/step - loss: 8.3068e-04 - accuracy: 1.0000
# Epoch 31/100
# 43/43 [==============================] - 0s 3ms/step - loss: 7.3838e-04 - accuracy: 1.0000
# Epoch 32/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.1645e-04 - accuracy: 1.0000
# Epoch 33/100
# 43/43 [==============================] - 0s 3ms/step - loss: 5.4567e-04 - accuracy: 1.0000
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.5206e-04 - accuracy: 1.0000
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.9069e-04 - accuracy: 1.0000
# Epoch 36/100
# 43/43 [==============================] - 0s 3ms/step - loss: 4.3225e-04 - accuracy: 1.0000
# Epoch 37/100
# 43/43 [==============================] - 0s 3ms/step - loss: 4.0470e-04 - accuracy: 1.0000
# Epoch 38/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.6844e-04 - accuracy: 1.0000
# Epoch 39/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.2571e-04 - accuracy: 1.0000
# Epoch 40/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.0516e-04 - accuracy: 1.0000
# Epoch 41/100
# 43/43 [==============================] - 0s 3ms/step - loss: 2.7280e-04 - accuracy: 1.0000
# Epoch 42/100
# 43/43 [==============================] - 0s 3ms/step - loss: 2.7397e-04 - accuracy: 1.0000
# Epoch 43/100
# 43/43 [==============================] - 0s 7ms/step - loss: 2.7418e-04 - accuracy: 1.0000
# Epoch 44/100
# 43/43 [==============================] - 0s 6ms/step - loss: 2.6337e-04 - accuracy: 1.0000
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.1956e-04 - accuracy: 1.0000
# Epoch 46/100
# 43/43 [==============================] - 0s 5ms/step - loss: 2.0445e-04 - accuracy: 1.0000
# Epoch 47/100
# 43/43 [==============================] - 0s 6ms/step - loss: 1.8170e-04 - accuracy: 1.0000
# Epoch 48/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.7922e-04 - accuracy: 1.0000
# Epoch 49/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.6782e-04 - accuracy: 1.0000
# Epoch 50/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4762e-04 - accuracy: 1.0000
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.5700e-04 - accuracy: 1.0000
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4049e-04 - accuracy: 1.0000
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3383e-04 - accuracy: 1.0000
# Epoch 54/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.2241e-04 - accuracy: 1.0000
# Epoch 55/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.2229e-04 - accuracy: 1.0000
# Epoch 56/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.1209e-04 - accuracy: 1.0000
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0914e-04 - accuracy: 1.0000
# Epoch 58/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0359e-04 - accuracy: 1.0000
# Epoch 59/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.8166e-05 - accuracy: 1.0000
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.0831e-05 - accuracy: 1.0000
# Epoch 61/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.2138e-05 - accuracy: 1.0000
# Epoch 62/100
# 43/43 [==============================] - 0s 1ms/step - loss: 8.2398e-05 - accuracy: 1.0000
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.8729e-05 - accuracy: 1.0000
# Epoch 64/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.6305e-05 - accuracy: 1.0000
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.4519e-05 - accuracy: 1.0000
# Epoch 66/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.0884e-05 - accuracy: 1.0000
# Epoch 67/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.4889e-05 - accuracy: 1.0000
# Epoch 68/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.3912e-05 - accuracy: 1.0000
# Epoch 69/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.1398e-05 - accuracy: 1.0000
# Epoch 70/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.7935e-05 - accuracy: 1.0000
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.6242e-05 - accuracy: 1.0000
# Epoch 72/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.3834e-05 - accuracy: 1.0000
# Epoch 73/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.2827e-05 - accuracy: 1.0000
# Epoch 74/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.9175e-05 - accuracy: 1.0000
# Epoch 75/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.7571e-05 - accuracy: 1.0000
# Epoch 76/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.5793e-05 - accuracy: 1.0000
# Epoch 77/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.2521e-05 - accuracy: 1.0000
# Epoch 78/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.1595e-05 - accuracy: 1.0000
# Epoch 79/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.2073e-05 - accuracy: 1.0000
# Epoch 80/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.9948e-05 - accuracy: 1.0000
# Epoch 81/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.7246e-05 - accuracy: 1.0000
# Epoch 82/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.5652e-05 - accuracy: 1.0000
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.4644e-05 - accuracy: 1.0000
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.2887e-05 - accuracy: 1.0000
# Epoch 85/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.2254e-05 - accuracy: 1.0000
# Epoch 86/100
# 43/43 [==============================] - 0s 1ms/step - loss: 3.3909e-05 - accuracy: 1.0000
# Epoch 87/100
# 43/43 [==============================] - 0s 1ms/step - loss: 3.0496e-05 - accuracy: 1.0000
# Epoch 88/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.9050e-05 - accuracy: 1.0000
# Epoch 89/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.7850e-05 - accuracy: 1.0000
# Epoch 90/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.6465e-05 - accuracy: 1.0000
# Epoch 91/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.5898e-05 - accuracy: 1.0000
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.4684e-05 - accuracy: 1.0000
# Epoch 93/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.4007e-05 - accuracy: 1.0000
# Epoch 94/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.3908e-05 - accuracy: 1.0000
# Epoch 95/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.2514e-05 - accuracy: 1.0000
# Epoch 96/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.1172e-05 - accuracy: 1.0000
# Epoch 97/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.1629e-05 - accuracy: 1.0000
# Epoch 98/100
# 43/43 [==============================] - 0s 1ms/step - loss: 2.0004e-05 - accuracy: 1.0000
# Epoch 99/100
# 43/43 [==============================] - 0s 1ms/step - loss: 1.9128e-05 - accuracy: 1.0000
# Epoch 100/100
# 43/43 [==============================] - 0s 1ms/step - loss: 1.9015e-05 - accuracy: 1.0000
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                620
#
#  dense_1 (Dense)             (None, 64)                1344
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6189 (24.18 KB)
# Trainable params: 6189 (24.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Test Accuracy: 96.50%

# %%
from keras.datasets import mnist
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData).astype('float32') / 255
test_data = test_images.reshape(test_images.shape[0], dimData).astype('float32') / 255
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Creating the network
model = Sequential([
    Dense(512, activation='relu', input_shape=(dimData,)),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

# Plotting the accuracy and loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Predicting a single image
def predict_single_image(image_data):
    image_data = image_data.reshape(1, dimData).astype('float32') / 255
    prediction = model.predict(image_data)
    predicted_class = np.argmax(prediction)
    return predicted_class

# Choose an image from the test set
image_index = 0  # Change this to see different predictions
predicted_class = predict_single_image(test_images[image_index])
print(f'Predicted class for image at index {image_index}: {predicted_class}')
plt.imshow(test_images[image_index], cmap='gray')
plt.title(f'Image at index {image_index} - Predicted as: {predicted_class}')
plt.show()

# Modify the model to use different activation functions and fewer layers for comparison
# You can adjust the following model architecture as needed
model_tanh = Sequential([
    Dense(512, activation='tanh', input_shape=(dimData,)),
    Dense(10, activation='softmax')
])

model_tanh.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model_tanh.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
               validation_data=(test_data, test_labels_one_hot))

# To compare performance without scaling, you would need to adjust the data preprocessing
# and re-train the model. This is not included here for brevity but can be done by removing
# the division by 255 in the data preprocessing steps.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2979 - accuracy: 0.9076 - val_loss: 0.1425 - val_accuracy: 0.9572
# Epoch 2/10
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1014 - accuracy: 0.9684 - val_loss: 0.0988 - val_accuracy: 0.9691
# Epoch 3/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0633 - accuracy: 0.9806 - val_loss: 0.1070 - val_accuracy: 0.9648
# Epoch 4/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0447 - accuracy: 0.9856 - val_loss: 0.0656 - val_accuracy: 0.9811
# Epoch 5/10
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0312 - accuracy: 0.9902 - val_loss: 0.1036 - val_accuracy: 0.9703
# Epoch 6/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 0.0630 - val_accuracy: 0.9818
# Epoch 7/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.0902 - val_accuracy: 0.9744
# Epoch 8/10
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.0648 - val_accuracy: 0.9817
# Epoch 9/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.0688 - val_accuracy: 0.9807
# Epoch 10/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0739 - val_accuracy: 0.9806
# 1/1 [==============================] - 0s 62ms/step
# Predicted class for image at index 0: 7
# Epoch 1/10
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3869 - accuracy: 0.8859 - val_loss: 0.2688 - val_accuracy: 0.9219
# Epoch 2/10
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2320 - accuracy: 0.9333 - val_loss: 0.2009 - val_accuracy: 0.9400
# Epoch 3/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1695 - accuracy: 0.9509 - val_loss: 0.1601 - val_accuracy: 0.9518
# Epoch 4/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1298 - accuracy: 0.9623 - val_loss: 0.1438 - val_accuracy: 0.9538
# Epoch 5/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1033 - accuracy: 0.9704 - val_loss: 0.1306 - val_accuracy: 0.9600
# Epoch 6/10
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0840 - accuracy: 0.9760 - val_loss: 0.0983 - val_accuracy: 0.9704
# Epoch 7/10
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0701 - accuracy: 0.9795 - val_loss: 0.0809 - val_accuracy: 0.9742
# Epoch 8/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0593 - accuracy: 0.9829 - val_loss: 0.0819 - val_accuracy: 0.9747
# Epoch 9/10
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0496 - accuracy: 0.9857 - val_loss: 0.0830 - val_accuracy: 0.9744
# Epoch 10/10
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0425 - accuracy: 0.9879 - val_loss: 0.0740 - val_accuracy: 0.9768
